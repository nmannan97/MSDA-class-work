# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("amanamaniyassouwe/mtcars")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.28k/2.28k [00:00<?, ?B/s]
# Extracting files...
# Path to dataset files: C:\Users\balto\.cache\kagglehub\datasets\amanamaniyassouwe\mtcars\versions\1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\balto\\.cache\\kagglehub\\datasets\\amanamaniyassouwe\\mtcars\\versions\\1\\data.csv")
df.head(5)
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
plt.subplot(1, 1, 1)
plt.scatter(df.index, df['mpg'])
plt.subplot(1, 1, 1)
plt.scatter(df.index, df['disp'])
plt.subplot(1, 1, 1)
plt.scatter(df.index, df['hp'])
plt.subplot(1, 1, 1)
plt.scatter(df.index, df['wt'])
plt.subplot(1, 1, 1)
plt.scatter(df.index,  df['am'])
#plt.scatter(df.index,, , , ,)

# %%
x = np.linspace(0.5, 3.5, 100)
y1 = 3+np.cos(x)
y2 = 1+np.cos(1+x/0.75)/2
y3 = np.random.uniform(y1, y2, len(x))

# %%
plt.subplot(1, 1, 1)
plt.plot(x, y1)
plt.subplot(1, 1, 1)
plt.plot(x, y2)
plt.subplot(1, 1, 1)
plt.scatter(x, y3)

# %% [markdown]
# https://public.tableau.com/app/profile/naeem.mannan/viz/MannanNaeem_HW1/Dashboard1#1
# ###
# https://public.tableau.com/app/profile/naeem.mannan/viz/NaeemMannan_HW1_Q3/Sheet2
